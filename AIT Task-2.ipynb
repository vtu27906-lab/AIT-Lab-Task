# %%
def objective_function(x):
    return -(x - 3) ** 2 + 9


def hill_climbing(start, step=1):
    current = start

    while True:
        current_value = objective_function(current)

        left = current - step
        right = current + step

        left_value = objective_function(left)
        right_value = objective_function(right)


        if left_value > current_value:
            current = left
        elif right_value > current_value:
            current = right
        else:
            break

    return current, objective_function(current)



start = int(input("Enter initial state: "))


state, value = hill_climbing(start)


print("Final state:", state)
print("Maximum objective value:", value)
# Out:
# Enter initial state: 0
# Final state: 3
# Maximum objective value: 9
